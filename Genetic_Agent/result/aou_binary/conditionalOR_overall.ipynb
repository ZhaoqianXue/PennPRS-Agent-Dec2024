# %%
import numpy as np
import pandas as pd

original_matrix = pd.read_csv("prs_conditioanlOR_matrix_260217_rootcode_qc.csv")
original_matrix = original_matrix.set_index("trait")
rank_matrix = pd.read_csv("prs_conditionalOR_matrix_260217_rootcode_rankmatrix.csv")
rank_matrix = rank_matrix.set_index("trait")
metainfo = pd.read_csv("../../disease_preprocess/pgs_metadata_260217.csv")
metainfo = metainfo.drop_duplicates(subset="PGS_ID", keep="first").set_index("PGS_ID")

# %% [markdown]
# ### Histogram of the Best Performing PGS

# %%
import matplotlib.pyplot as plt
matrix = original_matrix.copy()
max_list = []
for trait in matrix.index:
    max_list.append(max(matrix.loc[trait]))
    if max(matrix.loc[trait]) > 90:
        print(trait, max(matrix.loc[trait]))
plt.figure()
plt.hist(max_list, bins=100)
plt.xlabel("Best PGS performance (Adjusted AUC)")
plt.ylabel("Count")
plt.title("Histogram of Best Performing PGS")
plt.show()
# Out:
# C62 98.00287065596328
# C73 94.18698932587256
# E11 95.52470071776044
# I21 94.87900268779612
# I50 97.23665260611683
# I71 98.50610426791644
# M08 91.45693011952712

# %%
self_pgs_count = 0
same_chap_count = 0
others = 0
for trait in rank_matrix.index:

    best_pgs = rank_matrix.loc[trait].iloc[0]
    chapter = str(trait[0])

    if trait in best_pgs.split("__")[0].split("+"):
        self_pgs_count += 1
        continue
    
    elif any(chapter in item for item in best_pgs.split("__")[0].split("+")):
        same_chap_count += 1
    
    else:
        others += 1

counts = [self_pgs_count, same_chap_count, others]
labels = ["PGS for Target Trait", "PGS for Trait in Same Chapter", "Others"]
x = [0, 3, 6] 

plt.figure(figsize=(6,5))
plt.bar(x, counts, color=["skyblue", "orange", "green"], width=1.5)
plt.xticks(x, labels)
plt.ylabel("Number of Traits")
plt.title("Best Performing PGS for Each Traits")
for i, count in enumerate(counts):
    plt.text(x[i], count + 0.5, str(count), ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
from collections import Counter

best_self_pgs_rank = []
for trait in rank_matrix.index:

    for idx, m in enumerate(rank_matrix.loc[trait]):
        
        if trait in m.split("__")[0].split("+"):
            best_self_pgs_rank.append(idx + 1)
            if idx > 1000:
                print(trait)
            break


rank_counts = Counter(best_self_pgs_rank)
ranks = sorted(rank_counts.keys())
counts = [rank_counts[r] for r in ranks]

total_traits = len(best_self_pgs_rank)
num_top10 = sum(
    count for r, count in rank_counts.items() if r <= 10
)
ratio = num_top10 / total_traits

plt.figure(figsize=(8,5))
plt.plot(ranks, counts, '--', marker='o', markersize=4)

plt.text(
    2, max(counts)*1.2,
    f"≤10: {num_top10} ({ratio:.1%})",
    fontsize=12
)

plt.xlabel("Best Rank of PGS for Target Traits")
plt.ylabel("Number of Traits")
plt.title("Trait Counts by Rank of Self PGS")
plt.xscale('log')
plt.yscale('log')
plt.xticks([1, 10, 100, 1000], ["1", "10", "100", "1000"])
plt.yticks([1, 5, 10, 50], ["1", "5", "10", "50"])
plt.grid(0.6)
plt.tight_layout()
plt.show()
# Out:
# F43
# I49
# L28
# R94

# %% [markdown]
# ### Histogram of the Worse Performing PGS

# %%
matrix = original_matrix.copy()
max_list = []
for trait in matrix.index:
    max_list.append(min(matrix.loc[trait]))
plt.figure()
plt.hist(max_list, bins=100)
plt.xlabel("Worst PGS performance (Adjusted AUC)")
plt.ylabel("Count")
plt.title("Histogram of Worst Performing PGS")
plt.show()

# %% [markdown]
# ### Histogram of the PRS Performing Range

# %%
matrix = original_matrix.copy()
for trait in matrix.index:
    temp = max(matrix.loc[trait]) - min(matrix.loc[trait])
    max_list.append(temp)
    if temp > 90:
        print(trait, temp)
plt.hist(max_list, bins=100)
plt.xlabel("Best PGS performance - Worst PGS performance (Adjusted AUC)")
plt.ylabel("Count")
plt.title("Histogram of Performing Range")
plt.show()
# Out:
# C62 98.00269474685508
# C73 94.04269068337564
# E11 95.5188482215571
# I21 94.8495495379766
# I50 97.22561248983676
# I71 98.42210996275618
# M08 91.45455088487448

# %%
diff_dict = {}

for trait in matrix.index:
    values = matrix.loc[trait].values.astype(float)
    diff = np.nanmax(values) - np.nanmin(values)
    diff_dict[trait] = diff

large_diff_traits = [t for t, d in diff_dict.items() if d > 90]
print("Traits with performance range bigget than 90: ", large_diff_traits)
# Out:
# Traits with performance range bigget than 90:  ['C62', 'C73', 'E11', 'I21', 'I50', 'I71', 'M08']

# %% [markdown]
# ### Histogram of Range Between Median and the Best

# %%
matrix = original_matrix.copy()
max_list = [max(matrix.loc[trait]) - np.median(matrix.loc[trait]) for trait in matrix.index]
plt.figure()
plt.hist(max_list, bins=100)
plt.xlabel("Best PGS performance - Median PGS performance (Adj AUC)")
plt.ylabel("Count")
plt.title("Histogram of Performing Range")
plt.show()

# %%
diff_dict = {}

for trait in matrix.index:
    values = matrix.loc[trait].values.astype(float)
    diff = np.nanmax(values) - np.median(values)
    diff_dict[trait] = diff

large_diff_traits = [t for t, d in diff_dict.items() if d > 0.3]
print("Traits with performance range bigget than 0.3: ", large_diff_traits)
# Out:
# Traits with performance range bigget than 0.3:  ['C62', 'C73', 'O14']

# %% [markdown]
# ### Correlation: Number of Variants - Performance

# %%
def add_significance(ax, x1, x2, y, p):
    h = y * 0.05
    ax.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5)
    
    if p < 0.001:
        text = "***"
    elif p < 0.01:
        text = "**"
    elif p < 0.05:
        text = "*"
    else:
        text = "ns"
    
    ax.text((x1+x2)/2, y+h, text, ha='center', va='bottom')

# %%
num_variant_best = []
num_variant_median = []
num_variant_worst = []

for trait in rank_matrix.index:

    pgs_list = []
    num_list = []

    for m in rank_matrix.loc[trait]:

        if trait not in m.split("__")[0].split("+"):
            continue

        temp_id = m.split("__")[1]

        pgs_list.append(temp_id)

        num_var = metainfo.loc[temp_id]["num_variant"]
        num_list.append(num_var)

    if len(num_list) < 3:
        continue
    num_array = np.array(num_list)
    best = num_array[0]
    worst = num_array[-1]
    median = num_array[len(num_array) // 2]

    num_variant_best.append(best)
    num_variant_median.append(median)
    num_variant_worst.append(worst)

# %%
import matplotlib.pyplot as plt
from scipy.stats import kruskal, mannwhitneyu

# hypothesis testing
# overall test
stat, p_global = kruskal(
    num_variant_best,
    num_variant_median,
    num_variant_worst
)

print("Global p:", p_global)

# pairwise
p1 = mannwhitneyu(num_variant_best, num_variant_median).pvalue
p2 = mannwhitneyu(num_variant_best, num_variant_worst).pvalue
p3 = mannwhitneyu(num_variant_median, num_variant_worst).pvalue

fig, ax = plt.subplots(figsize=(6,5))

data = [num_variant_best, num_variant_median, num_variant_worst]

ax.boxplot(
    data,
    labels=["Best", "Median", "Worst"],
    showfliers=False
)

ax.set_yscale("log")
ax.set_ylabel("Number of Variants in PGS")
ax.set_title("Variant Count Across Performance Ranks")

# add pairwise significance
y_max = max([max(d) for d in data])

add_significance(ax, 1, 2, y_max*1.1, p1)
add_significance(ax, 1, 3, y_max*1.3, p2)
add_significance(ax, 2, 3, y_max*1.5, p3)

plt.tight_layout()
plt.show()
# Out:
# Global p: 6.244153929780466e-05

# %% [markdown]
# ### Correlation: Date Release - Performance

# %%
matrix = original_matrix.copy()
today = pd.Timestamp.today()

days_best = []
days_median = []
days_worst = []

for trait in rank_matrix.index:

    days_list = []

    for m in rank_matrix.loc[trait]:

        if trait not in m.split("__")[0].split("+"):
            continue

        temp_id = m.split("__")[1]

        release_date = pd.to_datetime(metainfo.loc[temp_id]["date_release"])
        days_diff = (today - release_date).days

        days_list.append(days_diff)

    if len(days_list) < 3:
        continue

    days_array = np.array(days_list)

    days_best.append(days_array[0])
    days_median.append(days_array[len(days_array)//2])
    days_worst.append(days_array[-1])

# %%
import matplotlib.pyplot as plt

num_variant_best = [x for x in days_best if pd.notna(x)]
num_variant_median = [x for x in days_median if pd.notna(x)]
num_variant_worst = [x for x in days_worst if pd.notna(x)]

# hypothesis testing
# overall test
stat, p_global = kruskal(
    num_variant_best,
    num_variant_median,
    num_variant_worst
)

print("Global p:", p_global)

# pairwise
p1 = mannwhitneyu(num_variant_best, num_variant_median).pvalue
p2 = mannwhitneyu(num_variant_best, num_variant_worst).pvalue
p3 = mannwhitneyu(num_variant_median, num_variant_worst).pvalue

fig, ax = plt.subplots(figsize=(6,5))

data = [num_variant_best, num_variant_median, num_variant_worst]

ax.boxplot(
    data,
    labels=["Best", "Median", "Worst"],
    showfliers=False
)

ax.set_ylabel("Days Since Release")
ax.set_title("Release Time Across Performance Ranks")

# add pairwise significance
y_max = max([max(d) for d in data])

add_significance(ax, 1, 2, y_max*1.05, p1)
add_significance(ax, 1, 3, y_max*1.08, p2)
add_significance(ax, 2, 3, y_max*1.10, p3)

plt.tight_layout()
plt.show()
# Out:
# Global p: 0.37433665077531064

# %% [markdown]
# ### Correlation: Reported Performance - Performance

# %% [markdown]
# #### Odds Ratio

# %%
from scipy.stats import norm

def beta_to_auc(beta):
    return norm.cdf(beta / np.sqrt(2))

def or_to_auc(OR):
    beta = np.log(OR)
    return norm.cdf(beta / np.sqrt(2))

def partial_r_to_auc(r):
    d = 2*r / np.sqrt(1 - r**2)
    return norm.cdf(d / np.sqrt(2))

def perpare_report_performance(eval_estimate: list, eval_ancestry: list, eval_metrics: list) -> float:
    result = []
    for idx, estimate in enumerate(eval_estimate):
        if not eval_ancestry[idx] == 'European':
            continue
        metric = eval_metrics[idx]
        if not metric == "Odds Ratio":
            continue
        result.append(estimate)
    if len(result) > 0:
        return float(np.mean(result))
    else:
        return np.nan

# %%
import ast
matrix = original_matrix.copy()
today = pd.Timestamp.today()

days_best = []
days_median = []
days_worst = []

for trait in rank_matrix.index:

    days_list = []

    for m in rank_matrix.loc[trait]:

        if trait not in m.split("__")[0].split("+"):
            continue

        temp_id = m.split("__")[1]

        eval_estimate = ast.literal_eval(metainfo.loc[temp_id]["eval_estimate"])
        eval_ancestry = ast.literal_eval(metainfo.loc[temp_id]["eval_ancestry"])
        eval_metrics = ast.literal_eval(metainfo.loc[temp_id]["eval_metrics"])
        num_var = perpare_report_performance(eval_estimate, eval_ancestry, eval_metrics)

        days_list.append(num_var)

    if len(days_list) < 3:
        continue

    days_array = np.array(days_list)

    days_best.append(days_array[0])
    days_median.append(days_array[len(days_array)//2])
    days_worst.append(days_array[-1])

# %%
import matplotlib.pyplot as plt
from scipy.stats import kruskal, mannwhitneyu

num_variant_best = [x for x in days_best if pd.notna(x)]
num_variant_median = [x for x in days_median if pd.notna(x)]
num_variant_worst = [x for x in days_worst if pd.notna(x)]

# hypothesis testing
# overall test
stat, p_global = kruskal(
    num_variant_best,
    num_variant_median,
    num_variant_worst
)

print("Global p:", p_global)

# pairwise
p1 = mannwhitneyu(num_variant_best, num_variant_median).pvalue
p2 = mannwhitneyu(num_variant_best, num_variant_worst).pvalue
p3 = mannwhitneyu(num_variant_median, num_variant_worst).pvalue

fig, ax = plt.subplots(figsize=(6,5))

data = [num_variant_best, num_variant_median, num_variant_worst]

ax.boxplot(
    data,
    labels=["Best", "Median", "Worst"],
    showfliers=False
)

ax.set_ylabel("Reported Odds Ratio (OR) in European Ancestry Cohorts")
ax.set_title("Reported Performance Across Performance Ranks")

# add pairwise significance
y_max = max([max(d) for d in data])

add_significance(ax, 1, 2, 1.9, p1)
add_significance(ax, 1, 3, 2.0, p2)
add_significance(ax, 2, 3, 2.1, p3)

plt.tight_layout()
plt.show()
# Out:
# Global p: 0.31152227883234584

# %% [markdown]
# #### Adjusted AUC

# %%
from scipy.stats import norm

def beta_to_auc(beta):
    return norm.cdf(beta / np.sqrt(2))

def or_to_auc(OR):
    beta = np.log(OR)
    return norm.cdf(beta / np.sqrt(2))

def partial_r_to_auc(r):
    d = 2*r / np.sqrt(1 - r**2)
    return norm.cdf(d / np.sqrt(2))

def perpare_report_performance(eval_estimate: list, eval_ancestry: list, eval_metrics: list) -> float:
    result = []
    for idx, estimate in enumerate(eval_estimate):
        if not eval_ancestry[idx] == 'European':
            continue
        metric = eval_metrics[idx]
        if not metric == "Area Under the Receiver-Operating Characteristic Curve":
            continue
        result.append(estimate)
    if len(result) > 0:
        return float(np.mean(result))
    else:
        return np.nan
    
import ast
matrix = original_matrix.copy()
today = pd.Timestamp.today()

days_best = []
days_median = []
days_worst = []

for trait in rank_matrix.index:

    days_list = []

    for m in rank_matrix.loc[trait]:

        if trait not in m.split("__")[0].split("+"):
            continue

        temp_id = m.split("__")[1]

        eval_estimate = ast.literal_eval(metainfo.loc[temp_id]["eval_estimate"])
        eval_ancestry = ast.literal_eval(metainfo.loc[temp_id]["eval_ancestry"])
        eval_metrics = ast.literal_eval(metainfo.loc[temp_id]["eval_metrics"])
        num_var = perpare_report_performance(eval_estimate, eval_ancestry, eval_metrics)

        days_list.append(num_var)

    if len(days_list) < 3:
        continue

    days_array = np.array(days_list)

    days_best.append(days_array[0])
    days_median.append(days_array[len(days_array)//2])
    days_worst.append(days_array[-1])

# %%
import matplotlib.pyplot as plt
from scipy.stats import kruskal, mannwhitneyu

num_variant_best = [x for x in days_best if pd.notna(x)]
num_variant_median = [x for x in days_median if pd.notna(x)]
num_variant_worst = [x for x in days_worst if pd.notna(x)]

# hypothesis testing
# overall test
stat, p_global = kruskal(
    num_variant_best,
    num_variant_median,
    num_variant_worst
)

print("Global p:", p_global)

# pairwise
p1 = mannwhitneyu(num_variant_best, num_variant_median).pvalue
p2 = mannwhitneyu(num_variant_best, num_variant_worst).pvalue
p3 = mannwhitneyu(num_variant_median, num_variant_worst).pvalue

fig, ax = plt.subplots(figsize=(6,5))

data = [num_variant_best, num_variant_median, num_variant_worst]

ax.boxplot(
    data,
    labels=["Best", "Median", "Worst"],
    showfliers=False
)

ax.set_ylabel("Reported Adjusted AUC in European Ancestry Cohorts")
ax.set_title("Reported Performance Across Performance Ranks")

# add pairwise significance
y_max = max([max(d) for d in data])

add_significance(ax, 1, 2, 0.90, p1)
add_significance(ax, 1, 3, 0.95, p2)
add_significance(ax, 2, 3, 1.00, p3)

plt.tight_layout()
plt.show()
# Out:
# Global p: 0.6044870643077854

# %% [markdown]
# #### Beta

# %%
print(np.unique(metainfo["eval_metrics"]))
# Out:
# ["['Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Odds Ratio', 'Hazard Ratio']"
#  "['Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve']"
#  "['Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'HR (Hazard Ratio; highest vs. lowest tertile of PRS)', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Hazard ratio (HR, top 5% vs bottom 95%)', 'Beta', 'Odds ratio (OR, top vs bottom PRS decile)', 'p', 'p']"
#  "['Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio']"
#  "['Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve']"
#  "['Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta']"
#  "['Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Beta', 'Beta', 'Beta', 'Beta']"
#  "['Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Odds Ratio', 'Hazard Ratio']"
#  "['Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Odds Ratio']"
#  "['Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve']"
#  "['Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Odds Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Hazard Ratio']"
#  "['Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Odds Ratio']"
#  "['Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve']"
#  "['Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Odds Ratio', 'Hazard Ratio (HR; highest vs. lowest quartile)', 'Hazard Ratio (HR; highest vs. lowest quartile)']"
#  "['Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Odds Ratio', 'Hazard Ratio']"
#  "['Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve']"
#  "['Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Beta', 'Beta', 'Beta']"
#  "['Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Odds Ratio', 'Hazard Ratio']"
#  "['Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Odds Ratio', 'Odds ratio (OR, bottom 10% vs. middle 20%)', 'Odds Ratio', 'Odds ratio (OR, top 10% vs. middle 20%)', 'Odds ratio (OR, bottom 10% vs. middle 20%)', 'Odds Ratio', 'Relative Risk (RR)', 'Relative Risk (RR: 30 - 55 years old)', 'Odds Ratio', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio (HR, top vs. bottom quartile)', 'Hazard Ratio (HR, top vs. bottom quartile)', 'Odds Ratio', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Odds Ratio', 'Concordance Statistic', 'Area Under the Receiver-Operating Characteristic Curve', 'Hazard Ratio (HR per change in transformed PRS)', 'Odds ratio (OR, PGS above median vs PGS below median)', 'Odds ratio (OR, PGS above median vs PGS below median)', 'Hazard Ratio', 'Hazard ratio (HR, intermediate vs low tertile)', 'Hazard ratio (HR, intermediate vs low tertile)', 'Hazard ratio (HR, intermediate vs low tertile)', 'Hazard ratio (HR, intermediate vs low tertile)', 'Hazard ratio (HR, non-carrier of P/LP/D variants in BRCA2, ATM, NBN, and PALB2 and high PRS vs. carrier of P/LP/D variants in BRCA2, ATM, NBN, and PALB2 and intermediate PRS)', 'Hazard ratio (HR, non-carrier of P/LP/D variants in BRCA2, ATM, NBN, and PALB2 and high PRS vs. carrier of P/LP/D variants in BRCA2, ATM, NBN, and PALB2 and intermediate PRS)', 'Hazard ratio (HR, non-carrier of P/LP/D variants in BRCA2, ATM, NBN, and PALB2 and high PRS vs. carrier of P/LP/D variants in BRCA2, ATM, NBN, and PALB2 and intermediate PRS)', 'Hazard Ratio']"
#  "['Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Odds Ratio']"
#  "['Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Odds ratio (OR, high vs low tertile)', 'Odds ratio (OR, positive VCA-IgA and high PRS vs. negative VCA-IgA and low PRS)']"
#  "['Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Relative Risk (RR; higest vs. lowest quartile PRS)']"
#  "['Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve']"
#  "['Area Under the Receiver-Operating Characteristic Curve', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Hazard Ratio']"
#  "['Area Under the Receiver-Operating Characteristic Curve', 'Concordance Statistic']"
#  "['Area Under the Receiver-Operating Characteristic Curve', 'Correlation', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio']"
#  "['Area Under the Receiver-Operating Characteristic Curve', 'Hazard Ratio (HR, top 25% vs bottom 25%)', 'Hazard Ratio (HR, top 25% vs bottom 25%)', 'Area Under the Receiver-Operating Characteristic Curve']"
#  "['Area Under the Receiver-Operating Characteristic Curve', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio']"
#  "['Area Under the Receiver-Operating Characteristic Curve', 'Hazard Ratio', 'Odds Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Hazard Ratio']"
#  "['Area Under the Receiver-Operating Characteristic Curve', 'Hazard Ratio']"
#  "['Area Under the Receiver-Operating Characteristic Curve', 'Hazard ratio (HR top 5% vs average)']"
#  "['Area Under the Receiver-Operating Characteristic Curve', 'Odds Ratio (OR, top 20% vs bottom 20%)']"
#  "['Area Under the Receiver-Operating Characteristic Curve', 'Odds Ratio', 'Area Under the Receiver-Operating Characteristic Curve', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Hazard ratio (HR, PRS above mean vs PRS below mean)', 'beta (PRS above mean vs PRS below mean)', 'beta (PRS above mean vs PRS below mean)', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio']"
#  "['Area Under the Receiver-Operating Characteristic Curve', 'Odds Ratio', 'Hazard Ratio']"
#  "['Area Under the Receiver-Operating Characteristic Curve', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Hazard Ratio']"
#  "['Area Under the Receiver-Operating Characteristic Curve', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Area Under the Receiver-Operating Characteristic Curve', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Concordance Statistic', 'Concordance Statistic', 'Hazard Ratio', 'Hazard Ratio', 'Concordance Statistic', 'Concordance Statistic', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic']"
#  "['Area Under the Receiver-Operating Characteristic Curve', 'Odds Ratio']"
#  "['Area Under the Receiver-Operating Characteristic Curve']"
#  "['Beta', 'Area Under the Receiver-Operating Characteristic Curve', 'Sensitivity', 'Area Under the Receiver-Operating Characteristic Curve', 'Odds ratio, OR (high vs low risk)']"
#  "['Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta']"
#  "['Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta']"
#  "['Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Hazard ratio (HR, highest vs. lowest quintile)', 'Hazard ratio (HR, highest vs. lowest quintile)', 'Hazard ratio (HR, highest vs. lowest quintile)', 'Hazard ratio (HR, highest vs. lowest quintile)', 'Hazard ratio (HR, highest vs. lowest quintile)', 'Hazard ratio (HR, highest vs. lowest quintile)']"
#  "['Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta']"
#  "['Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta']"
#  "['Beta', 'Beta', 'Beta', 'Beta', 'Hazard Ratio']"
#  "['Beta', 'Beta', 'Beta', 'Beta']"
#  "['Beta', 'Beta', 'Beta', 'Odds Ratio', 'Beta', 'Beta', 'Beta', 'Beta', 'Odds Ratio', 'Odds Ratio']"
#  "['Beta', 'Beta', 'Beta']"
#  "['Beta', 'Beta', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Beta', 'Beta', 'Beta', 'Beta']"
#  "['Beta', 'Beta']"
#  "['Beta', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Beta', 'Hazard Ratio']"
#  "['Beta', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio']"
#  "['Beta', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio']"
#  "['Beta']" "['Coefficient']"
#  "['Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Odds Ratio', 'Hazard Ratio']"
#  "['Concordance Statistic', 'Concordance Statistic', 'Hazard Ratio', 'Hazard Ratio']"
#  "['Concordance Statistic', 'Concordance Statistic']"
#  "['Concordance Statistic']"
#  "['Difference in mean cognition per decacde increase in age per 1-SD higher GRS (%)', 'Difference in mean cognition per decacde increase in age per 1-SD higher GRS (%)', 'Difference in mean cognition per decacde increase in age per 1-SD higher GRS (%)', 'Difference in mean cognition per decacde increase in age per 1-SD higher GRS (%)', 'Difference in mean cognition per decacde increase in age per 1-SD higher GRS (%)', 'Difference in mean cognition per decacde increase in age per 1-SD higher GRS (%)', 'Difference in mean cognition per decacde increase in age per 1-SD higher GRS (%)', 'Difference in mean cognition per decacde increase in age per 1-SD higher GRS (%)', 'Difference in mean cognition per decacde increase in age per 1-SD higher GRS (%)', 'Difference in mean cognition per decacde increase in age per 1-SD higher GRS (%)', 'Difference in mean cognition per decacde increase in age per 1-SD higher GRS (%)', 'Difference in mean cognition per decacde increase in age per 1-SD higher GRS (%)', 'Difference in mean cognition per decacde increase in age per 1-SD higher GRS (%)']"
#  "['Difference of PRS (deltaPRS; melanoma family cases vs. unrelated controls)', 'Difference of PRS (deltaPRS; unaffected melanoma family members vs. unrelated controls)']"
#  "['HR (Hazard ratio; top 2% vs. average risk)', 'z-test (p-value) <', 'HR (Hazard ratio; top 2% vs. average risk)', 'z-test (p-value) <', 'HR (Hazard ratio; top 2% vs. average risk)', 'z-test (p-value) <', 'Hazard Ratio (HR; top 20% vs. rest)', 'Hazard Ratio (HR; top 20% vs. rest)', 'Hazard Ratio (HR; top 20% vs. rest)', 'Hazard Ratio (HR; top 20% vs. rest)', 'Hazard Ratio (HR; top 20% vs. rest)', 'Hazard Ratio (HR top 20% vs. bottom 20%)', 'Hazard Ratio (HR top 2% vs. middle 40%)', 'Hazard Ratio (HR bottom 20% vs. middle 40%)', 'Hazard Ratio (HR top 20% vs. bottom 20%)', 'Hazard Ratio (top 2% vs. middle 40%)', 'Hazard Ratio (bottom 20% vs. middle 40%)', 'Hazard Ratio (HR, top 5% vs. middle 40%)', 'Hazard Ratio (HR, top 20% vs. bottom 20%)', 'Hazard Ratio (HR, bottom 20% vs. middle 40%)', 'Hazard Ratio (HR, top 5% vs. middle 40%)', 'Hazard Ratio (HR, top 20% vs. bottom 20%)', 'Hazard Ratio (HR, bottom 20% vs. middle 40%)', 'Hazard Ratio (HR, top 5% vs. middle 40%)', 'Hazard Ratio (HR, top 20% vs. bottom 20%)', 'Hazard Ratio (HR, bottom 20% vs. middle 40%)']"
#  "['HR (High genetic risk: top 5% vs. bottom 5% of PRS)', 'Odds ratio (OR,  high vs low risk)', 'Odds Ratio', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Hazard Ratio', 'Hazard ratio (HR, high vs low PGS quartile)', 'Hazard ratio (HR, high vs low PGS quartile)']"
#  "['HR (highest vs. lowest quintile of PGS)', 'Odds Ratio', 'Beta']"
#  "['HR (top vs. bottom quartiles of GRS)', 'HR (top vs. bottom quartiles of GRS)']"
#  "['Hazard  ratio (HR,  high vs low risk)', 'Hazard Ratio']"
#  "['Hazard Ratio (HR top 20% vs. bottom 20%)', 'Hazard Ratio (HR top 2% vs. middle 40%)', 'Hazard Ratio (HR bottom 20% vs. middle 40%)', 'Hazard Ratio (top 20% vs. bottom 20%)', 'Hazard Ratio (top 2% vs. middle 40%)', 'Hazard Ratio (bottom 20% vs. middle 40%)', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio']"
#  "['Hazard Ratio (HR, high vs. low genetic risk)', 'Incidence (%)', 'Hazard ratio (HR, high deprivation and PRS in top quintile vs. low-moderate deprivation and PRS in bottom quintile)', 'Hazard ratio (HR, high deprivation and PRS in top quintile vs. low-moderate deprivation and PRS in bottom quintile)', 'Hazard ratio (HR, top vs bottom PRS quintile)', 'Hazard Ratio']"
#  "['Hazard Ratio (HR, middle vs. lowest tertile)', 'Hazard Ratio (HR, highest vs. lowest tertile)', 'Hazard Ratio (HR, highest vs. lowest tertile)', 'Hazard Ratio (HR, highest vs. lowest tertile)', 'Hazard Ratio (HR, middle vs. lowest tertile)', 'Hazard Ratio (HR, middle vs. lowest tertile)', 'Hazard Ratio (HR, highest vs. lowest tertile)', 'Hazard Ratio (HR, highest vs. lowest tertile)', 'Hazard ratio (HR, high UPF consumption and highest PRS quartile vs. low UPF consumption and lowest PRS quartile)']"
#  "['Hazard Ratio (HR, top 5% vs. middle 40%)', 'Hazard Ratio (HR, top 20% vs. bottom 20%)', 'Hazard Ratio (HR, bottom 20% vs. middle 40%)', 'Hazard Ratio (HR, top 5% vs. middle 40%)', 'Hazard Ratio (HR, top 20% vs. bottom 20%)', 'Hazard Ratio (HR, bottom 20% vs. middle 40%)', 'Hazard Ratio (HR, top 5% vs. middle 40%)', 'Hazard Ratio (HR, top 20% vs. bottom 20%)', 'Hazard Ratio (HR, bottom 20% vs. middle 40%)']"
#  "['Hazard Ratio', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve']"
#  "['Hazard Ratio', 'Area Under the Receiver-Operating Characteristic Curve']"
#  "['Hazard Ratio', 'Beta', 'Hazard ratio (HR, high vs low PRS tertile)', 'Hazard Ratio', 'Odds Ratio', 'Hazard Ratio']"
#  "['Hazard Ratio', 'Concordance Statistic', 'Concordance Statistic', 'Area Under the Receiver-Operating Characteristic Curve']"
#  "['Hazard Ratio', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Odds Ratio', 'Hazard Ratio']"
#  "['Hazard Ratio', 'Concordance Statistic', 'Concordance Statistic', 'Hazard Ratio', 'Odds Ratio']"
#  "['Hazard Ratio', 'Hazard Ratio (HR, highest vs lowest quintile)', 'Hazard Ratio (HR, highest vs lowest quintile)', 'Hazard Ratio (HR, highest vs lowest quintile)', 'Hazard Ratio (HR, highest vs lowest quintile)', 'Hazard Ratio', 'Hazard Ratio']"
#  "['Hazard Ratio', 'Hazard Ratio (HR, top 20% vs bottom 20%)', 'Hazard Ratio (HR, top 20% vs bottom 20%)', 'Hazard Ratio (HR, middle 60% vs bottom 20%)', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio']"
#  "['Hazard Ratio', 'Hazard Ratio', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve']"
#  "['Hazard Ratio', 'Hazard Ratio', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta']"
#  "['Hazard Ratio', 'Hazard Ratio', 'Concordance Statistic', 'Odds Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio']"
#  "['Hazard Ratio', 'Hazard Ratio', 'Concordance Statistic', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio']"
#  "['Hazard Ratio', 'Hazard Ratio', 'Concordance Statistic', 'Odds Ratio']"
#  "['Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio (HR; top 20% of score vs bottom 20%)', 'Hazard Ratio (HR; top 20% of score vs bottom 20%)', 'Hazard Ratio (HR; top 20% of score vs bottom 20%)', 'Agatston score (mean, top 20% of GRS)', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio (HR, top 25% vs bottom 25%)', 'Hazard Ratio (HR, top 25% vs bottom 25%)', 'Hazard Ratio (HR, top 25% vs bottom 25%)', 'Incidence Rate Ratio (IRR, top vs bottom PGS quintiles)', 'Incidence Rate Ratio (IRR, top vs bottom PGS quintiles)', 'Incidence Rate Ratio (IRR, top vs bottom PGS quintiles)', 'Odds Ratio (OR, top vs bottom PGS quintiles)', 'Hazard Ratio (HR, top vs bottom PGS quintiles)']"
#  "['Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio']"
#  "['Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic', 'Concordance Statistic']"
#  "['Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio (HR, top 25% vs bottom 25%)', 'Hazard Ratio (HR, top 25% vs bottom 25%)', 'Hazard Ratio (HR, top 25% vs bottom 25%)']"
#  "['Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Concordance Statistic']"
#  "['Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio']"
#  "['Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio']"
#  "['Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio']"
#  "['Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Hazard Ratio']"
#  "['Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio']"
#  "['Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio']"
#  "['Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio']"
#  "['Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio']"
#  "['Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Hazard Ratio']"
#  "['Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio']"
#  "['Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio']"
#  "['Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard ratio (HR, high vs low tertile)', 'Hazard Ratio']"
#  "['Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Hazard Ratio']"
#  "['Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio']"
#  "['Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio']"
#  "['Hazard Ratio', 'Hazard Ratio', 'Hazard ratio (HR, high vs low quintile)']"
#  "['Hazard Ratio', 'Hazard Ratio', 'NRI (net reclassification improvement)', 'NRI (net reclassification improvement)', 'Odds ratio (OR, high vs low PGS tertile)', 'Odds ratio (OR, high vs low PGS tertile)', 'Odds ratio (OR, high vs low PGS tertile)']"
#  "['Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio']"
#  "['Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio']"
#  "['Hazard Ratio', 'Hazard Ratio', 'Odds Ratio']"
#  "['Hazard Ratio', 'Hazard Ratio', 'p-value (pvalue, evolocumab and high PRS vs. placebo and low PRS)']"
#  "['Hazard Ratio', 'Hazard Ratio']"
#  "['Hazard Ratio', 'Hazard ratio (HR, high air pollution and PRS in top tertile vs low air pollution and PRS in bottom tertile)']"
#  "['Hazard Ratio', 'Hazard ratio (HR, high vs low PRS tertile)']"
#  "['Hazard Ratio', 'Hazard ratio (HR, high vs low risk)']"
#  "['Hazard Ratio', 'Hazard ratio (HR, outdoor light time in summer >3h/day and PRS in top tertile vs. outdoor light time in summer <2-3 h/day and PRS in bottom tertile)', 'Hazard ratio (HR, outdoor light time in winter >2 h/day and PRS in top tertile vs. outdoor light time in winter <1-2 h/day and PRS in bottom tertile)', 'Hazard ratio (HR, outdoor light time on average >2.5 h/day and PRS in top tertile vs. outdoor light time on average 1.5-2.5 h/day and PRS in bottom tertile)', 'Odds Ratio', 'Hazard Ratio']"
#  "['Hazard Ratio', 'Hazard ratio (HR, unfavorable lifestyle and high PRS vs. favorable life style and low PRS)']"
#  "['Hazard Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio']"
#  "['Hazard Ratio', 'Odds Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Hazard Ratio']"
#  "['Hazard Ratio', 'Odds Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio']"
#  "['Hazard Ratio', 'Odds Ratio', 'Hazard Ratio']"
#  "['Hazard Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Odds Ratio (OR; top 20% vs. rest)', 'Odds Ratio (OR; top 20% vs. rest)', 'Odds Ratio (OR; top 20% vs. rest)', 'Odds Ratio (OR; top 20% vs. rest)', 'Odds Ratio (OR; top 20% vs. rest)', 'Odds Ratio (OR; top 20% vs. rest)', 'Beta (top 20% vs. rest)', 'Beta (top 20% vs. rest)', 'Beta (top 20% vs. rest)', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Beta', 'Beta', 'Beta', 'Beta', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio']"
#  "['Hazard Ratio', 'Odds Ratio', 'Odds Ratio']"
#  "['Hazard Ratio', 'Odds Ratio']"
#  "['Hazard Ratio', 'Relative Risk ', 'Hazard Ratio', 'Relative Risk ', 'Relative Risk ', 'Relative Risk ', 'Relative Risk ', 'Relative Risk ']"
#  "['Hazard Ratio']"
#  "['Hazard ratio (HR, >=3 vs <0.5 risk)', 'Hazard ratio (HR, >=3 vs <0.5 risk)']"
#  "['Hazard ratio (HR, high vs low PRS quintile)']"
#  "['Hazard ratio (HR, high vs low PRS tertile)', 'Hazard ratio (HR, high vs low PRS tertile)', 'Hazard ratio (HR, high vs low PRS tertile)', 'Hazard ratio (HR, high laxative use and PRS in top tertile vs no laxative use and PRS in bottom tertile)', 'Hazard ratio (HR, high laxative use and PRS in top tertile vs no laxative use and PRS in bottom tertile)', 'Hazard ratio (HR, high laxative use and PRS in top tertile vs no laxative use and PRS in bottom tertile)']"
#  "['Hazard ratio (HR, high vs low PRS)', 'Hazard ratio (HR, high air pollution and high PRS vs low air pollution and low PRS)']"
#  "['Hazard ratio (HR, high vs low quintile)', 'Hazard ratio (HR, poor lifestyle and high PRS vs. ideal lifestyle and low PRS)']"
#  "['Hazard ratio (HR, high vs low quintile)', 'Odds Ratio', 'Hazard Ratio']"
#  "['Hazard ratio (HR, high vs low tertile)', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio']"
#  "['Hazard ratio (HR, high vs low tertile)', 'Hazard ratio (HR, high vs low tertile)', 'Hazard ratio (HR, high vs low tertile)', 'Hazard ratio (HR, high vs low tertile)', 'Hazard ratio (HR, high vs low tertile)', 'Hazard ratio (HR, high vs low tertile)', 'Hazard ratio (HR, high vs low tertile)', 'Hazard ratio (HR, high vs low tertile)', 'Hazard ratio (HR, high vs low tertile)']"
#  "['Hazard ratio (HR, high vs low tertile)', 'Hazard ratio (HR, high vs low tertile)', 'Hazard ratio (HR, high vs low tertile)']"
#  "['Hazard ratio (HR, high vs low tertile)', 'Hazard ratio (HR, high vs low tertile)']"
#  "['Hazard ratio (HR, high vs low tertile)', 'Hazard ratio (HR, poor lifestyle and high PRS vs. ideal lifestyle and low PRS)']"
#  "['Hazard ratio (HR, high vs low tertile)', 'Hazard ratio (HR, with diabetes and high PRS vs. without diabetes and low PRS)']"
#  "['Hazard ratio (HR, highest PRS quintile and heavy smokers vs lowest PRS quintile and never smokers)', 'Hazard ratio (HR, highest vs lowest PRS quintiles)']"
#  "['Hazard ratio (HR, per IQR change in PRS)', 'Hazard ratio (HR, PRS in top tertile and high PM2.5 exposure vs PRS in bottom tertile and low PM2.5 exposure)']"
#  "['Hazard ratio (HR, second hand smoke exposure and high PRS vs. no exposure and low PRS)']"
#  "['Hazard ratio (HR, top 20% vs. bottom 20%)', 'Hazard ratio (HR, top 20% vs. bottom 20%)', 'Hazard ratio (HR, top 20% vs. bottom 20%)', 'Hazard ratio (HR, top 20% vs. bottom 20%)', 'Hazard ratio (HR, top 20% vs. bottom 20%)', 'Hazard ratio (HR, top 20% vs. bottom 20%)', 'Hazard ratio (HR, top 20% vs. bottom 20%)', 'Hazard ratio (HR, top 20% vs. bottom 20%)', 'Hazard ratio (HR, top 20% vs. bottom 20%)', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio']"
#  "['Hazard ratio (HR, top 50% vs bottom 50% of PRS)', 'Hazard ratio (HR, unhealthy lifestyle and PRS in top 50% vs healthy lifestyle and PRS in bottom 50%)']"
#  "['Hazard ratio (elevated risk factor burden and high PRS vs optimal risk factor burden and low PRS)', 'Hazard ratio (elevated risk factor burden and high PRS vs optimal risk factor burden and low PRS)', 'Hazard ratio (elevated risk factor burden and high PRS vs optimal risk factor burden and low PRS)']"
#  "['Incremental R2 (Full model versus model with only covariates)', 'Odds Ratio', 'Hazard Ratio']"
#  "['Incremental R2 (Full model versus model with only covariates)']"
#  "['Incremental R2 (full model vs. covariates alone)', 'Incremental R2 (full model vs. covariates alone)', 'Incremental R2 (full model vs. covariates alone)', 'Incremental R2 (full model vs. covariates alone)', 'Odds Ratio', 'Hazard Ratio']"
#  "['Incremental R2 (full model vs. covariates alone)', 'Incremental R2 (full model vs. covariates alone)', 'Incremental R2 (full model vs. covariates alone)', 'Incremental R2 (full model vs. covariates alone)']"
#  "['Incremental R2 (full model when combined with BOLT-LMM vs. covariates alone)', 'Incremental R2 (full model when combined with BOLT-LMM vs. covariates alone)', 'Incremental R2 (full model when combined with BOLT-LMM vs. covariates alone)', 'Incremental R2 (full model when combined with BOLT-LMM vs. covariates alone)', 'Odds Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Hazard Ratio']"
#  "['Incremental R2 (full model when combined with BOLT-LMM vs. covariates alone)', 'Incremental R2 (full model when combined with BOLT-LMM vs. covariates alone)', 'Incremental R2 (full model when combined with BOLT-LMM vs. covariates alone)', 'Incremental R2 (full model when combined with BOLT-LMM vs. covariates alone)']"
#  "['Mean realative risk', 'Odds Ratio (OR; high vs. average risk groups)', 'Area Under the Receiver-Operating Characteristic Curve']"
#  "['Mean realative risk', 'Odds Ratio (OR; high vs. average risk groups)']"
#  "['Nagelkerke pseudo-R2']"
#  "['OR (Odds Ratio, per risk allele)', 'Odds Ratio', 'Hazard Ratio']"
#  "['OR (per 1-point increase in PRS)', 'OR (above vs. below 50th percentile of PRS)']"
#  "['OR (top 10% vs rest of population)', 'OR (top 10% vs rest of population)', 'OR (top 10% vs rest of population)', 'OR (top 10% vs rest of population)', 'OR (top 10% vs rest of population)', 'OR (top 10% vs rest of population)', 'OR (top 10% vs rest of population)', 'OR (top 10% vs rest of population)', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve']"
#  "['OR (top 10% vs rest of population)', 'OR (top 10% vs rest of population)']"
#  "['OR (top vs 2nd quintile)', 'OR (top vs 2nd quintile)', 'Odds Ratio']"
#  "['Odds Ratio (OR per 1 point increase)', 'Odds Ratio (OR per 1 point increase)']"
#  "['Odds Ratio (OR, per interquartile range unit change)', 'Odds Ratio (OR, per interquartile range unit change)', 'Odds Ratio (OR, per interquartile range unit change)', 'Odds Ratio (OR, per interquartile range unit change)', 'Odds Ratio (OR, per interquartile range unit change)', 'Odds Ratio (OR, per interquartile range unit change)', 'Odds Ratio (OR, per interquartile range unit change)', 'Odds Ratio (OR, per interquartile range unit change)', 'Odds Ratio (OR, per interquartile range unit change)', 'Odds Ratio (OR, per interquartile range unit change)', 'Odds Ratio (OR, per interquartile range unit change)', 'Odds Ratio (OR, per interquartile range unit change)', 'Odds Ratio (OR, per interquartile range unit change)', 'Odds Ratio (OR, per interquartile range unit change)', 'Odds Ratio (OR, per interquartile range unit change)', 'Odds Ratio (OR, per interquartile range unit change)', 'Odds Ratio (OR, per interquartile range unit change)', 'Area Under the Receiver-Operating Characteristic Curve']"
#  "['Odds Ratio (OR, top 20% vs bottom 20%)']"
#  "['Odds Ratio (OR, top 20% vs remaining 80% of score distribution)', 'Odds Ratio (OR, top 10% vs remaining 90% of score distribution)', 'Odds Ratio (OR, top 10% vs remaining 95% of score distribution)', 'Odds Ratio (OR, top 1% vs remaining 99% of score distribution)', 'Beta', 'Beta', 'Beta', 'Beta']"
#  "['Odds Ratio (OR, top vs average percentile)']"
#  "['Odds Ratio', 'Area Under the Receiver-Operating Characteristic Curve', 'Odds Ratio', 'Area Under the Receiver-Operating Characteristic Curve']"
#  "['Odds Ratio', 'Area Under the Receiver-Operating Characteristic Curve', 'Odds Ratio', 'Odds Ratio']"
#  "['Odds Ratio', 'Area Under the Receiver-Operating Characteristic Curve']"
#  "['Odds Ratio', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta']"
#  "['Odds Ratio', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta']"
#  "['Odds Ratio', 'Beta', 'Beta']" "['Odds Ratio', 'Beta']"
#  "['Odds Ratio', 'Concordance Statistic']"
#  "['Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Area Under the Receiver-Operating Characteristic Curve']"
#  "['Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Beta', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio']"
#  "['Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Area Under the Receiver-Operating Characteristic Curve', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Odds Ratio']"
#  "['Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio']"
#  "['Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio']"
#  "['Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio']"
#  "['Odds Ratio', 'Hazard Ratio', 'Hazard Ratio']"
#  "['Odds Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Concordance Statistic', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Concordance Statistic', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Area Under the Receiver-Operating Characteristic Curve', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio']"
#  "['Odds Ratio', 'Hazard Ratio']"
#  "['Odds Ratio', 'Hazard ratio (HR, high vs low PRS)', 'Hazard ratio (HR, high air pollution and high PRS vs low air pollution and low PRS)']"
#  "['Odds Ratio', 'Odds Ratio', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Odds Ratio', 'Odds Ratio', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Odds Ratio', 'Beta']"
#  "['Odds Ratio', 'Odds Ratio', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve']"
#  "['Odds Ratio', 'Odds Ratio', 'Area Under the Receiver-Operating Characteristic Curve', 'Hazard ratio (HR, high vs middle percentile)', 'Area Under the Receiver-Operating Characteristic Curve', 'Hazard ratio (HR, high vs middle percentile)']"
#  "['Odds Ratio', 'Odds Ratio', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta']"
#  "['Odds Ratio', 'Odds Ratio', 'Beta']"
#  "['Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve']"
#  "['Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Hazard Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Hazard Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Beta', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Beta', 'Odds Ratio', 'Odds Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Concordance Statistic']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio (OR, top 10% vs bottom 10%)', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Area Under the Receiver-Operating Characteristic Curve']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Beta', 'Odds Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Area Under the Receiver-Operating Characteristic Curve']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Beta']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Beta', 'Odds Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Beta']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Area Under the Receiver-Operating Characteristic Curve']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Area Under the Receiver-Operating Characteristic Curve', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Beta', 'Beta', 'Beta', 'Beta', 'Odds Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Beta', 'Beta']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Area Under the Receiver-Operating Characteristic Curve', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Beta', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Odds Ratio', 'Odds Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Hazard Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Hazard Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio']"
#  "['Odds Ratio', 'Odds Ratio', 'Odds Ratio']"
#  "['Odds Ratio', 'Odds Ratio']"
#  "['Odds Ratio', 'Odds ratio (OR, high vs low tertile)', 'Odds ratio (OR, high vs low tertile)', 'Odds ratio (OR, high vs low tertile)']"
#  "['Odds Ratio', 'Odds ratio (OR, top PRS quintile vs bottom PRS quintile)']"
#  "['Odds Ratio', 'p-value (p, Environmental Tobacco Smoke at home and at work and high PRS vs Environmental Tobacco Smoke never and low PRS)']"
#  "['Odds Ratio']" "['Odds ratio (OR, <median)']"
#  "['Odds ratio (OR, high vs low PGS tertile)']"
#  "['Odds ratio (OR, high vs low PRS quintile)', 'Area Under the Receiver-Operating Characteristic Curve']"
#  "['Odds ratio (OR, high vs low tertile)']"
#  "['Odds ratio (OR, top 10% vs. middle 50%)', 'Odds ratio (OR, top 1% vs. middle 50%)', 'Odds ratio (OR, bottom 10% vs. middle 50%)', 'Odds ratio (OR, bottom 1% vs. middle 50%)']"
#  "['Odds ratio (OR, top vs bottom PGS quartile)', 'Odds ratio (OR, top vs bottom PGS quartile)']"
#  "['PGS R2  (no covariates)']"
#  "['Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Odds Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Hazard Ratio']"
#  "['Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Hazard Ratio', 'Odds Ratio', 'Hazard Ratio']"
#  "['Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio']"
#  "['Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio']"
#  "['Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)']"
#  "['Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)']"
#  "['Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)']"
#  "['Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)']"
#  "['Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)', 'Partial Correlation (partial-r)']"
#  "['Percentage of cases with risk >95th percentile of UKB psoraisis cases', 'Percentage of cases with risk >95th percentile of UKB psoraisis cases']"
#  "['Percentage of screened individuals diagnosed with cancer', 'Odds Ratio', 'Odds Ratio']"
#  "['Proportion of the variance explained', 'Hazard Ratio']"
#  "['Proportion of the variance explained', 'Incremental R2 (full-covars)', 'Proportion of the variance explained', 'Proportion of the variance explained', 'Proportion of the variance explained']"
#  "['Proportion of the variance explained', 'Odds Ratio']"
#  "['Proportion of the variance explained', 'Positive Predictive Value (PPV)', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Concordance Statistic', 'Concordance Statistic', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio', 'Odds Ratio']"
#  "['Proportion of the variance explained', 'Proportion of the variance explained', 'Proportion of the variance explained', 'Proportion of the variance explained', 'Proportion of the variance explained', 'Proportion of the variance explained', 'Proportion of the variance explained', 'Proportion of the variance explained', 'Proportion of the variance explained', 'Proportion of the variance explained']"
#  "['Proportion of the variance explained', 'Proportion of the variance explained', 'Proportion of the variance explained', 'Proportion of the variance explained', 'Proportion of the variance explained']"
#  "['Proportion of the variance explained']"
#  "['Relative Rate (RR)', 'Relative Rate (RR)', 'Relative Rate (RR)', 'Relative Rate (RR)', 'Relative Rate (RR)', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve']"
#  "['Z', 'Beta', 'Beta', 'Beta']"
#  "['p (PRS in cases vs controls)', 'p (PRS in cases vs controls)']"
#  "['p (interaction between PRS and sleep pattern)']"
#  "['p', 'Beta', 'Beta', 'Beta', 'Area Under the Receiver-Operating Characteristic Curve', 'Area Under the Receiver-Operating Characteristic Curve']"
#  "['partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²', 'partial R²']"
#  "['partial-R2', 'partial-R2', 'partial-R2', 'partial-R2', 'partial-R2', 'partial-R2', 'partial-R2', 'partial-R2', 'partial-R2']"
#  "['r (correlation between between binned quantiles of PHS-predicted and empirical age of AD onset)', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta', 'Beta']"
#  '[]']

# %%
from scipy.stats import norm

def beta_to_auc(beta):
    return norm.cdf(beta / np.sqrt(2))

def or_to_auc(OR):
    beta = np.log(OR)
    return norm.cdf(beta / np.sqrt(2))

def partial_r_to_auc(r):
    d = 2*r / np.sqrt(1 - r**2)
    return norm.cdf(d / np.sqrt(2))

def perpare_report_performance(eval_estimate: list, eval_ancestry: list, eval_metrics: list) -> float:
    result = []
    for idx, estimate in enumerate(eval_estimate):
        if not eval_ancestry[idx] == 'European':
            continue
        metric = eval_metrics[idx]
        if metric not in ["partial R²", "partial-R2"]:
            continue
        result.append(estimate)
    if len(result) > 0:
        return float(np.mean(result))
    else:
        return np.nan
    
import ast
matrix = original_matrix.copy()
today = pd.Timestamp.today()

days_best = []
days_median = []
days_worst = []

for trait in rank_matrix.index:

    days_list = []

    for m in rank_matrix.loc[trait]:

        if trait not in m.split("__")[0].split("+"):
            continue

        temp_id = m.split("__")[1]

        eval_estimate = ast.literal_eval(metainfo.loc[temp_id]["eval_estimate"])
        eval_ancestry = ast.literal_eval(metainfo.loc[temp_id]["eval_ancestry"])
        eval_metrics = ast.literal_eval(metainfo.loc[temp_id]["eval_metrics"])
        num_var = perpare_report_performance(eval_estimate, eval_ancestry, eval_metrics)

        days_list.append(num_var)

    if len(days_list) < 3:
        continue

    days_array = np.array(days_list)

    days_best.append(days_array[0])
    days_median.append(days_array[len(days_array)//2])
    days_worst.append(days_array[-1])

# %%
print(len(num_variant_best))
# Out:
# 1

# %%
import matplotlib.pyplot as plt
from scipy.stats import kruskal, mannwhitneyu

num_variant_best = [x for x in days_best if pd.notna(x)]
num_variant_median = [x for x in days_median if pd.notna(x)]
num_variant_worst = [x for x in days_worst if pd.notna(x)]

# hypothesis testing
# overall test
stat, p_global = kruskal(
    num_variant_best,
    num_variant_median,
    num_variant_worst
)

print("Global p:", p_global)

# pairwise
p1 = mannwhitneyu(num_variant_best, num_variant_median).pvalue
p2 = mannwhitneyu(num_variant_best, num_variant_worst).pvalue
p3 = mannwhitneyu(num_variant_median, num_variant_worst).pvalue

fig, ax = plt.subplots(figsize=(6,5))

data = [num_variant_best, num_variant_median, num_variant_worst]

ax.boxplot(
    data,
    labels=["Best", "Median", "Worst"],
    showfliers=False
)

ax.set_ylabel("Reported Adjusted AUC in European Ancestry Cohorts")
ax.set_title("Reported Performance Across Performance Ranks")

# add pairwise significance
y_max = max([max(d) for d in data])

add_significance(ax, 1, 2, 0.90, p1)
add_significance(ax, 1, 3, 0.95, p2)
add_significance(ax, 2, 3, 1.00, p3)

plt.tight_layout()
plt.show()
# Out:
# Global p: 0.36787944117144245
